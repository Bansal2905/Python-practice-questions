# %%
import pandas as pd

# %%
df = pd.read_csv("Car_sales.csv")

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
# Only show inital 5 records
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0        Acura  Integra              16.919        16.360    Passenger
# 1        Acura       TL              39.384        19.875    Passenger
# 2        Acura       CL              14.114        18.225    Passenger
# 3        Acura       RL               8.588        29.725    Passenger
# 4         Audi       A4              20.397        22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Kerb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
df.tail(10)
# Out:
#     Manufacturer   Model  Sales_in_thousands  resale_value Vehicle_type  \
# 147   Volkswagen  Passat              51.102        16.725    Passenger
# 148   Volkswagen  Cabrio               9.569        16.575    Passenger
# 149   Volkswagen     GTI               5.596        13.760    Passenger
# 150   Volkswagen  Beetle              49.463           NaN    Passenger
# 151        Volvo     S40              16.957           NaN    Passenger
# 152        Volvo     V40               3.545           NaN    Passenger
# 153        Volvo     S70              15.245           NaN    Passenger
# 154        Volvo     V70              17.531           NaN    Passenger
# 155        Volvo     C70               3.493           NaN    Passenger
# 156        Volvo     S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 147               21.20          1.8       150.0      106.4   68.5   184.1
# ...

# %%
df.head(15)
# Out:
#    Manufacturer        Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0         Acura      Integra              16.919        16.360    Passenger
# 1         Acura           TL              39.384        19.875    Passenger
# 2         Acura           CL              14.114        18.225    Passenger
# 3         Acura           RL               8.588        29.725    Passenger
# 4          Audi           A4              20.397        22.255    Passenger
# 5          Audi           A6              18.780        23.555    Passenger
# 6          Audi           A8               1.380        39.000    Passenger
# 7           BMW         323i              19.747           NaN    Passenger
# 8           BMW         328i               9.231        28.675    Passenger
# 9           BMW         528i              17.527        36.125    Passenger
# 10        Buick      Century              91.561        12.475    Passenger
# ...

# %%
# No duplocated rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # If there are duplicates then run df.drop_duplicates()

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# resale_value          36
# Vehicle_type           0
# Price_in_thousands     2
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Kerb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        3
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %% [markdown]
# # Drop them

# %%
df.dropna()
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# 5           Audi       A6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 145   Volkswagen     Golf               9.761        11.425    Passenger
# 146   Volkswagen    Jetta              83.721        13.240    Passenger
# 147   Volkswagen   Passat              51.102        16.725    Passenger
# 148   Volkswagen   Cabrio               9.569        16.575    Passenger
# 149   Volkswagen      GTI               5.596        13.760    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %% [markdown]
# # You have dropped alomost 25% of data

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       CL              14.114        18.225    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
cols = list(df.columns)

# %%
cols.remove('resale_value')

# %%
cols
# Out:
# ['Manufacturer',
#  'Model',
#  'Sales_in_thousands',
#  'Vehicle_type',
#  'Price_in_thousands',
#  'Engine_size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Kerb_weight',
#  'Fuel_capacity',
#  'Fuel_efficiency',
#  'Latest_Launch',
#  'Power_perf_factor']

# %%
df.dropna(subset = cols,inplace = True)

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# 5           Audi       A6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %% [markdown]
# # Inplace is making changes without reassigning

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# resale_value          35
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Kerb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
df.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0         Acura      Integra              16.919        16.360    Passenger
# 1         Acura           TL              39.384        19.875    Passenger
# 3         Acura           RL               8.588        29.725    Passenger
# 4          Audi           A4              20.397        22.255    Passenger
# 5          Audi           A6              18.780        23.555    Passenger
# 6          Audi           A8               1.380        39.000    Passenger
# 7           BMW         323i              19.747           NaN    Passenger
# 8           BMW         328i               9.231        28.675    Passenger
# 9           BMW         528i              17.527        36.125    Passenger
# 10        Buick      Century              91.561        12.475    Passenger
# 11        Buick        Regal              39.350        13.740    Passenger
# ...

# %%
df["Difference"] = df["Price_in_thousands"] - df["resale_value"]

# %%
df.head(50)
# Out:
#    Manufacturer           Model  Sales_in_thousands  resale_value  \
# 0         Acura         Integra              16.919        16.360
# 1         Acura              TL              39.384        19.875
# 3         Acura              RL               8.588        29.725
# 4          Audi              A4              20.397        22.255
# 5          Audi              A6              18.780        23.555
# 6          Audi              A8               1.380        39.000
# 7           BMW            323i              19.747           NaN
# 8           BMW            328i               9.231        28.675
# 9           BMW            528i              17.527        36.125
# 10        Buick         Century              91.561        12.475
# 11        Buick           Regal              39.350        13.740
# 12        Buick     Park Avenue              27.851        20.190
# 13        Buick         LeSabre              83.257        13.360
# ...

# %%
df_resale = df.dropna()[["Manufacturer","Difference"]]

# %%
df_resale = df_resale.groupby("Manufacturer").mean()

# %%
df_resale.reset_index(inplace = True)

# %%
df_resale
# Out:
#    Manufacturer  Difference
# 0         Acura    8.646667
# 1          Audi   11.710000
# 2           BMW    3.750000
# 3         Buick   11.840000
# 4      Cadillac   14.698333
# 5     Chevrolet    6.933750
# 6      Chrysler    8.234000
# 7         Dodge    6.811667
# 8          Ford    8.960500
# 9         Honda    4.720000
# 10      Hyundai    4.634000
# 11     Infiniti    9.775000
# 12         Jeep    5.638333
# 13        Lexus    7.963333
# 14      Lincoln   20.080000
# 15   Mercedes-B   14.368750
# 16      Mercury    6.778333
# 17   Mitsubishi    7.905286
# 18       Nissan    9.555200
# 19   Oldsmobile   11.255500
# 20     Plymouth    5.998333
# 21      Pontiac    8.588000
# 22      Porsche    5.998333
# 23       Saturn    2.310000
# 24       Toyota    5.277250
# 25   Volkswagen    3.713000

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 3          Acura       RL               8.588        29.725    Passenger
# 4           Audi       A4              20.397        22.255    Passenger
# 5           Audi       A6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 152        Volvo      V40               3.545           NaN    Passenger
# 153        Volvo      S70              15.245           NaN    Passenger
# 154        Volvo      V70              17.531           NaN    Passenger
# 155        Volvo      C70               3.493           NaN    Passenger
# 156        Volvo      S80              18.969           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df = pd.merge(df,df_resale,how = "inner",on = "Manufacturer")

# %%
df.drop(columns = ["Difference_x"],inplace = True)

# %%
df.rename(columns = {"Difference_y":"Average Diffrerence"},inplace = True)

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       RL               8.588        29.725    Passenger
# 3           Audi       A4              20.397        22.255    Passenger
# 4           Audi       A6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 136   Volkswagen    Jetta              83.721        13.240    Passenger
# 137   Volkswagen   Passat              51.102        16.725    Passenger
# 138   Volkswagen   Cabrio               9.569        16.575    Passenger
# 139   Volkswagen      GTI               5.596        13.760    Passenger
# 140   Volkswagen   Beetle              49.463           NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# resale_value           24
# Vehicle_type            0
# Price_in_thousands      0
# Engine_size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Kerb_weight             0
# Fuel_capacity           0
# Fuel_efficiency         0
# Latest_Launch           0
# Power_perf_factor       0
# Average Diffrerence     0
# dtype: int64

# %%
def replace_resale(row):
    if pd.isnull(row["resale_value"]):
        return row["Price_in_thousands"] - row["Average Diffrerence"]
    else:
        return row["resale_value"]

# %% [markdown]
# # Apply function

# %%
df["resale_value"] = df.apply(replace_resale,axis = 1)

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          Acura  Integra              16.919        16.360    Passenger
# 1          Acura       TL              39.384        19.875    Passenger
# 2          Acura       RL               8.588        29.725    Passenger
# 3           Audi       A4              20.397        22.255    Passenger
# 4           Audi       A6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 136   Volkswagen    Jetta              83.721        13.240    Passenger
# 137   Volkswagen   Passat              51.102        16.725    Passenger
# 138   Volkswagen   Cabrio               9.569        16.575    Passenger
# 139   Volkswagen      GTI               5.596        13.760    Passenger
# 140   Volkswagen   Beetle              49.463        12.187    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# resale_value           0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Kerb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# Average Diffrerence    0
# dtype: int64
